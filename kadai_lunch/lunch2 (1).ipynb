# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/lunch/train.csv')
df_train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %%
df_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/lunch/test.csv')
df_test.head()
# Out:
#     datetime week  soldout        name   kcal remarks event  payday weather  \
# 0  2014-10-1    水        1       メンチカツ  420.0     NaN   NaN     NaN       雨
# 1  2014-10-2    木        0   バーベキューチキン  415.0     NaN   NaN     NaN       曇
# 2  2014-10-3    金        0  豚肉のマスタード焼き  405.0     NaN   NaN     NaN      晴れ
# 3  2014-10-6    月        1        麻婆春雨  400.0     NaN   NaN     NaN       雨
# 4  2014-10-7    火        0    厚揚げ肉みそ炒め  430.0     NaN   NaN     NaN      晴れ
#
#   precipitation  temperature
# 0             0         20.2
# 1            --         23.9
# 2            --         28.7
# 3           0.5         21.5
# 4            --         22.1

# %%
import seaborn as sns

# %%
# 基本統計量
print(df_train.describe())
print(df_test.describe())
# Out:
#                 y     soldout        kcal  payday  temperature
# count  207.000000  207.000000  166.000000    10.0   207.000000
# mean    86.623188    0.449275  404.409639     1.0    19.252174
# std     32.882448    0.498626   29.884641     0.0     8.611365
# min     29.000000    0.000000  315.000000     1.0     1.200000
# 25%     57.000000    0.000000  386.000000     1.0    11.550000
# 50%     78.000000    0.000000  408.500000     1.0    19.800000
# 75%    113.000000    1.000000  426.000000     1.0    26.100000
# max    171.000000    1.000000  462.000000     1.0    34.600000
#          soldout        kcal  payday  temperature
# count  40.000000   36.000000     2.0    40.000000
# mean    0.425000  421.083333     1.0    18.665000
# std     0.500641   13.626392     0.0     4.401838
# min     0.000000  396.000000     1.0     9.200000
# 25%     0.000000  411.500000     1.0    15.250000
# 50%     0.000000  420.000000     1.0    19.000000
# 75%     1.000000  428.500000     1.0    21.650000
# max     1.000000  460.000000     1.0    28.700000

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (207, 12)
# (40, 11)

# %%
# 欠損
df_train.isnull().sum()
# Out:
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %%
# 数値データの外れ値を確認する箱ひげ図
num_cols = df_train.select_dtypes(include=["number"]).columns

plt.figure(figsize=(10, 6))
sns.boxplot(data=df_train[num_cols])
plt.title("数値データの外れ値確認")
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20516 (\N{CJK UNIFIED IDEOGRAPH-5024}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12487 (\N{KATAKANA LETTER DE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12540 (\N{KATAKANA-HIRAGANA PROLONGED SOUND MARK}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12479 (\N{KATAKANA LETTER TA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22806 (\N{CJK UNIFIED IDEOGRAPH-5916}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12428 (\N{HIRAGANA LETTER RE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30906 (\N{CJK UNIFIED IDEOGRAPH-78BA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 35469 (\N{CJK UNIFIED IDEOGRAPH-8A8D}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 外れ値をIQRで抽出する関数
def detect_outliers(df, cols):
    outlier_dict = {}
    for col in cols:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR

        # 外れ値に該当するデータ
        outliers = df[(df[col] < lower) | (df[col] > upper)][col]
        outlier_dict[col] = {
            "件数": outliers.shape[0],
            "外れ値リスト": outliers.values
        }
    return outlier_dict

# 数値列を対象に外れ値確認
num_cols = df_train.select_dtypes(include=["number"]).columns
outlier_results = detect_outliers(df_train, num_cols)

# 結果表示
for col, info in outlier_results.items():
    print(f"特徴量: {col}")
    print(f"  外れ値件数: {info['件数']}")
    print(f"  外れ値リスト: {info['外れ値リスト'][:20]} ...")  # 多い場合は先頭20件だけ表示
    print("-" * 40)
# Out:
# 特徴量: y
#   外れ値件数: 0
#   外れ値リスト: [] ...
# ----------------------------------------
# 特徴量: soldout
#   外れ値件数: 0
#   外れ値リスト: [] ...
# ----------------------------------------
# 特徴量: kcal
#   外れ値件数: 3
#   外れ値リスト: [315. 325. 324.] ...
# ----------------------------------------
# 特徴量: payday
#   外れ値件数: 0
#   外れ値リスト: [] ...
# ----------------------------------------
# 特徴量: temperature
#   外れ値件数: 0
#   外れ値リスト: [] ...
# ----------------------------------------

# %%
# 学習データの欠損値の補完
# 1. kcal → 中央値で補完
if "kcal" in df_train.columns:
    median_kcal = df_train["kcal"].median()
    df_train["kcal"].fillna(median_kcal, inplace=True)

# 2. remarks → 使用しない（削除）
if "remarks" in df_train.columns:
    df_train.drop(columns=["remarks"], inplace=True)

# 3. event → 欠損は0、値があれば1
if "event" in df_train.columns:
    df_train["event"] = df_train["event"].notna().astype(int)

# 4. payday → 欠損は0
if "payday" in df_train.columns:
    df_train["payday"].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-1461079249.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["kcal"].fillna(median_kcal, inplace=True)
# /tmp/ipython-input-1461079249.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train["payday"].fillna(0, inplace=True)

# %%
# テストデータの欠損値の補完
# kcal → 中央値補完（train の中央値を使う）
if "kcal" in df_test.columns:
    df_test["kcal"].fillna(median_kcal, inplace=True)

# remarks → 削除
if "remarks" in df_test.columns:
    df_test.drop(columns=["remarks"], inplace=True)

# event → 欠損は0、値があれば1
if "event" in df_test.columns:
    df_test["event"] = df_test["event"].notna().astype(int)

# payday → 欠損は0
if "payday" in df_test.columns:
    df_test["payday"].fillna(0, inplace=True)
# Out:
# /tmp/ipython-input-2712454853.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test["kcal"].fillna(median_kcal, inplace=True)
# /tmp/ipython-input-2712454853.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test["payday"].fillna(0, inplace=True)

# %%
df_train.head()
df_test.head()
# Out:
#     datetime week  soldout        name   kcal  event  payday weather  \
# 0  2014-10-1    水        1       メンチカツ  420.0      0     0.0       雨
# 1  2014-10-2    木        0   バーベキューチキン  415.0      0     0.0       曇
# 2  2014-10-3    金        0  豚肉のマスタード焼き  405.0      0     0.0      晴れ
# 3  2014-10-6    月        1        麻婆春雨  400.0      0     0.0       雨
# 4  2014-10-7    火        0    厚揚げ肉みそ炒め  430.0      0     0.0      晴れ
#
#   precipitation  temperature
# 0             0         20.2
# 1            --         23.9
# 2            --         28.7
# 3           0.5         21.5
# 4            --         22.1

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       207 non-null    object
#  1   y              207 non-null    int64
#  2   week           207 non-null    object
#  3   soldout        207 non-null    int64
#  4   name           207 non-null    object
#  5   kcal           207 non-null    float64
#  6   event          207 non-null    int64
#  7   payday         207 non-null    float64
#  8   weather        207 non-null    object
#  9   precipitation  207 non-null    object
#  10  temperature    207 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 17.9+ KB

# %%
df_train["precipitation"].unique()
# Out:
# array(['--', '0.5', '0', '1.5', '1', '6', '6.5', '2.5'], dtype=object)

# %%
df_train[df_train["precipitation"]=="--"]
# Out:
#        datetime    y week  soldout          name   kcal  event  payday  \
# 0    2013-11-18   90    月        0      厚切りイカフライ  408.5      0     0.0
# 1    2013-11-19  101    火        1       手作りヒレカツ  408.5      0     0.0
# 2    2013-11-20  118    水        0    白身魚唐揚げ野菜あん  408.5      0     0.0
# 3    2013-11-21  120    木        1        若鶏ピリ辛焼  408.5      0     0.0
# 4    2013-11-22  130    金        1      ビッグメンチカツ  408.5      0     0.0
# ..          ...  ...  ...      ...           ...    ...    ...     ...
# 200   2014-9-19   45    金        0       厚切イカフライ  400.0      0     0.0
# 201   2014-9-22   29    月        0           筑前煮  395.0      0     0.0
# 204   2014-9-26   45    金        0      ランチビュッフェ  408.5      1     0.0
# 205   2014-9-29   56    月        1      豚肉と玉子の炒め  404.0      0     0.0
# 206   2014-9-30   40    火        0  鶏肉とカシューナッツ炒め  398.0      0     0.0
#
#     weather precipitation  temperature
# 0        快晴            --         19.8
# 1        快晴            --         17.0
# 2        快晴            --         15.5
# 3        快晴            --         15.2
# 4        快晴            --         16.1
# ..      ...           ...          ...
# 200      薄曇            --         23.6
# 201      晴れ            --         25.2
# 204      晴れ            --         27.1
# 205      快晴            --         26.6
# 206      快晴            --         28.1
#
# [169 rows x 11 columns]

# %%
df_train_drop=df_train.drop("precipitation", axis=1)
df_train_drop.head()
# Out:
#      datetime    y week  soldout        name   kcal  event  payday weather  \
# 0  2013-11-18   90    月        0    厚切りイカフライ  408.5      0     0.0      快晴
# 1  2013-11-19  101    火        1     手作りヒレカツ  408.5      0     0.0      快晴
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん  408.5      0     0.0      快晴
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼  408.5      0     0.0      快晴
# 4  2013-11-22  130    金        1    ビッグメンチカツ  408.5      0     0.0      快晴
#
#    temperature
# 0         19.8
# 1         17.0
# 2         15.5
# 3         15.2
# 4         16.1

# %%
df_train=df_train_drop

# %%
# datetime を日付型に変換
df_train["datetime"] = pd.to_datetime(df_train["datetime"])
df_test["datetime"] = pd.to_datetime(df_test["datetime"])

# 月と曜日を特徴量化
for df in [df_train, df_test]:
    df["month"] = df["datetime"].dt.month
    df["dayofweek"] = df["datetime"].dt.dayofweek  # 0=月曜, 6=日曜

# %%
# 目的変数
y = df_train["y"]

# 説明変数（datetimeは除外してOK、代わりに month と dayofweek を使う）
X = df_train.drop(["y", "datetime"], axis=1)
X_test = df_test.drop(["datetime"], axis=1)

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.0.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (2.2.2)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (1.16.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.9.0->category_encoders) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)

# %%
X
# Out:
#     week  soldout          name   kcal  event  payday weather  temperature  \
# 0      月        0      厚切りイカフライ  408.5      0     0.0      快晴         19.8
# 1      火        1       手作りヒレカツ  408.5      0     0.0      快晴         17.0
# 2      水        0    白身魚唐揚げ野菜あん  408.5      0     0.0      快晴         15.5
# 3      木        1        若鶏ピリ辛焼  408.5      0     0.0      快晴         15.2
# 4      金        1      ビッグメンチカツ  408.5      0     0.0      快晴         16.1
# ..   ...      ...           ...    ...    ...     ...     ...          ...
# 202    水        1   白身魚のマスタード焼き  408.0      0     0.0       曇         24.8
# 203    木        0       牛カルビ焼き肉  394.0      0     0.0       曇         25.4
# 204    金        0      ランチビュッフェ  408.5      1     0.0      晴れ         27.1
# 205    月        1      豚肉と玉子の炒め  404.0      0     0.0      快晴         26.6
# 206    火        0  鶏肉とカシューナッツ炒め  398.0      0     0.0      快晴         28.1
#
#      month  dayofweek
# 0       11          0
# 1       11          1
# 2       11          2
# 3       11          3
# 4       11          4
# ..     ...        ...
# 202      9          2
# 203      9          3
# 204      9          4
# 205      9          0
# 206      9          1
#
# [207 rows x 10 columns]

# %%
df_test_drop=df_test.drop("precipitation", axis=1)
df_test_drop.head()
# Out:
#     datetime week  soldout        name   kcal  event  payday weather  \
# 0 2014-10-01    水        1       メンチカツ  420.0      0     0.0       雨
# 1 2014-10-02    木        0   バーベキューチキン  415.0      0     0.0       曇
# 2 2014-10-03    金        0  豚肉のマスタード焼き  405.0      0     0.0      晴れ
# 3 2014-10-06    月        1        麻婆春雨  400.0      0     0.0       雨
# 4 2014-10-07    火        0    厚揚げ肉みそ炒め  430.0      0     0.0      晴れ
#
#    temperature  month  dayofweek
# 0         20.2     10          2
# 1         23.9     10          3
# 2         28.7     10          4
# 3         21.5     10          0
# 4         22.1     10          1

# %%
import datetime
s = '2014/10/1 20:30'
s_format = '%Y/%m/%d %H:%M'
dt = datetime.datetime.strptime(s, s_format)

# %%
dt.year
# Out:
# 2014

# %%
list_datetime = []

# %%
for i in range(len(df_train)):
  s = df_train["datetime"][i]
  print(s)
  s_format = '%Y-%m-%d %H:%M'
  print(s)
  dt = datetime.datetime.strptime(s, s_format)
  list_datetime.append([dt.year,dt.day, dt,month])
  print(YearEnd)
# Out:
# 2013-11-18 00:00:00
# 2013-11-18 00:00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2344344590.py in <cell line: 0>()
#       4   s_format = '%Y-%m-%d %H:%M'
#       5   print(s)
# ----> 6   dt = datetime.datetime.strptime(s, s_format)
#       7   list_datetime.append([dt.year,dt.day, dt,month])
#       8   print(YearEnd)
#
# TypeError: strptime() argument 1 must be str, not Timestamp

# %%
dt
# Out:
# datetime.datetime(2014, 10, 1, 20, 30)

# %%
df_test=df_test_drop

# %%
X
# Out:
#     week  soldout          name   kcal  event  payday weather  temperature  \
# 0      月        0      厚切りイカフライ  408.5      0     0.0      快晴         19.8
# 1      火        1       手作りヒレカツ  408.5      0     0.0      快晴         17.0
# 2      水        0    白身魚唐揚げ野菜あん  408.5      0     0.0      快晴         15.5
# 3      木        1        若鶏ピリ辛焼  408.5      0     0.0      快晴         15.2
# 4      金        1      ビッグメンチカツ  408.5      0     0.0      快晴         16.1
# ..   ...      ...           ...    ...    ...     ...     ...          ...
# 202    水        1   白身魚のマスタード焼き  408.0      0     0.0       曇         24.8
# 203    木        0       牛カルビ焼き肉  394.0      0     0.0       曇         25.4
# 204    金        0      ランチビュッフェ  408.5      1     0.0      晴れ         27.1
# 205    月        1      豚肉と玉子の炒め  404.0      0     0.0      快晴         26.6
# 206    火        0  鶏肉とカシューナッツ炒め  398.0      0     0.0      快晴         28.1
#
#      month  dayofweek
# 0       11          0
# 1       11          1
# 2       11          2
# 3       11          3
# 4       11          4
# ..     ...        ...
# 202      9          2
# 203      9          3
# 204      9          4
# 205      9          0
# 206      9          1
#
# [207 rows x 10 columns]

# %%
X_test
# Out:
#    week  soldout            name   kcal  event  payday weather precipitation  \
# 0     水        1           メンチカツ  420.0      0     0.0       雨             0
# 1     木        0       バーベキューチキン  415.0      0     0.0       曇            --
# 2     金        0      豚肉のマスタード焼き  405.0      0     0.0      晴れ            --
# 3     月        1            麻婆春雨  400.0      0     0.0       雨           0.5
# 4     火        0        厚揚げ肉みそ炒め  430.0      0     0.0      晴れ            --
# 5     水        0    完熟トマトのホットカレー  420.0      0     0.0      晴れ            --
# 6     木        0          豚キムチ炒め  435.0      1     0.0       曇            --
# 7     金        0          ポークカレー  408.5      0     1.0      薄曇            --
# 8     火        0         若鶏梅肉包揚げ  408.0      0     0.0      快晴            --
# 9     水        1         ミックスグリル  450.0      0     0.0       雨           1.5
# 10    木        0      豚肉と白菜の中華炒め  400.0      0     0.0      晴れ            --
# 11    金        0            ヒレカツ  415.0      1     0.0      快晴            --
# 12    月        1             豚柳川  426.0      0     0.0      薄曇            --
# 13    火        0         ポーク生姜焼き  410.0      0     0.0       雨             0
# 14    水        1            麻婆豆腐  415.0      0     0.0       雨             0
# 15    木        1       ビーフストロガノフ  428.0      0     0.0       雨           0.5
# 16    金        0            唐揚げ丼  408.5      0     0.0      快晴            --
# 17    月        1           マス塩焼き  407.0      0     0.0      薄曇            --
# 18    火        1        チンジャオロース  425.0      0     0.0      快晴            --
# 19    水        0         厚切イカフライ  430.0      0     0.0      快晴            --
# 20    木        0     鶏肉と野菜の黒胡椒炒め  426.0      0     0.0      晴れ            --
# 21    金        0             八宝菜  436.0      0     0.0       曇            --
# 22    火        0         豚肉の生姜焼き  440.0      0     0.0      晴れ            --
# 23    水        1           ハンバーグ  425.0      0     0.0       曇            --
# 24    木        1    彩り野菜と鶏肉の黒酢あん  410.0      0     0.0       曇            --
# 25    金        0          ポークカレー  408.5      0     0.0      晴れ            --
# 26    月        0             親子煮  412.0      0     1.0      快晴            --
# 27    火        0   ポークのバーベキューソテー  426.0      0     0.0       曇             0
# 28    水        0          鶏肉の唐揚げ  418.0      0     0.0       曇            --
# 29    木        1         白身魚味噌焼き  396.0      1     0.0      快晴            --
# 30    金        1      エビフライ・エビカツ  427.0      0     0.0      快晴            --
# 31    月        1      野菜ごろごろシチュー  433.0      0     0.0      薄曇            --
# 32    火        1            麻婆豆腐  409.0      0     0.0      快晴            --
# 33    水        0  ベルギー風チキンのクリーム煮  430.0      0     0.0      快晴            --
# 34    木        1          スタミナ炒め  421.0      0     0.0       曇            --
# 35    金        0           ロコモコ丼  408.5      0     0.0      快晴            --
# 36    火        1     なすと挽肉のはさみ揚げ  460.0      0     0.0       雨           1.5
# 37    水        1         鶏肉の治部煮風  415.0      0     0.0       雨             1
# 38    木        0             牛丼風  420.0      0     0.0      快晴            --
# 39    金        0    鶏肉のスイートチリソース  416.0      0     0.0       曇            --
#
#     temperature  month  dayofweek
# 0          20.2     10          2
# 1          23.9     10          3
# 2          28.7     10          4
# 3          21.5     10          0
# 4          22.1     10          1
# 5          23.3     10          2
# 6          22.5     10          3
# 7          26.1     10          4
# 8          26.8     10          1
# 9          15.6     10          2
# 10         18.6     10          3
# 11         23.0     10          4
# 12         23.9     10          0
# 13         20.2     10          1
# 14         15.5     10          2
# 15         14.7     10          3
# 16         18.7     10          4
# 17         22.7     10          0
# 18         19.1     10          1
# 19         19.6     10          2
# 20         19.6     10          3
# 21         18.8     10          4
# 22         18.9     11          1
# 23         16.0     11          2
# 24         19.2     11          3
# 25         20.1     11          4
# 26         21.2     11          0
# 27         14.7     11          1
# 28         14.4     11          2
# 29         19.5     11          3
# 30         15.8     11          4
# 31         14.3     11          0
# 32         16.1     11          1
# 33         14.9     11          2
# 34         10.5     11          3
# 35         14.9     11          4
# 36         11.4     11          1
# 37          9.2     11          2
# 38         15.1     11          3
# 39         15.3     11          4

# %%
df_X_test_drop=df_X_test.drop("precipitation", axis=1)
df_X_test_drop.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-451534453.py in <cell line: 0>()
# ----> 1 df_X_test_drop=df_X_test.drop("precipitation", axis=1)
#       2 df_X_test_drop.head()
#
# NameError: name 'df_X_test' is not defined

# %%
# categoryencoder
import category_encoders as ce
list_cols = ['week', 'name', 'weather']
ce_ohe = ce.OneHotEncoder(cols=list_cols, handle_unknown='impute')

X_encoded = ce_ohe.fit_transform(X)
X_test_encoded = ce_ohe.transform(X_test)

print("学習データ shape:", X_encoded.shape)
print("テストデータ shape:", X_test_encoded.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3079741133.py in <cell line: 0>()
#       5
#       6 X_encoded = ce_ohe.fit_transform(X)
# ----> 7 X_test_encoded = ce_ohe.transform(X_test)
#       8
#       9 print("学習データ shape:", X_encoded.shape)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/category_encoders/utils.py in transform(self, X, override_return_df)
#     664         # first check the type
#     665         X = convert_input(X, deep=True)
# --> 666         self._check_transform_inputs(X)
#     667
#     668         if not list(self.cols):
#
# /usr/local/lib/python3.12/dist-packages/category_encoders/utils.py in _check_transform_inputs(self, df)
#     512         # then make sure that it is the right size
#     513         if df.shape[1] != self._dim:
# --> 514             raise ValueError(f'Unexpected input dimension {df.shape[1]}, expected {self._dim}')
#     515
#     516     def _drop_invariants(
#
# ValueError: Unexpected input dimension 11, expected 10

# %%
df_drop_encoded=X_encoded.drop("precipitation", axis=1)
df_drop_encoded.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1738165250.py in <cell line: 0>()
# ----> 1 df_drop_encoded=X_encoded.drop("precipitation", axis=1)
#       2 df_drop_encoded.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['precipitation'] not found in axis"

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, LassoCV
from sklearn.metrics import mean_squared_error

# %%
# 説明変数と目的変数に分割
X_train, X_valid, y_train, y_valid = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42
)

# %%
# スケーリング
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid)
X_test_scaled  = scaler.transform(X_test_encoded)

# %%
# モデル学習（線形回帰）
linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)
y_pred_lin = linreg.predict(X_valid_scaled)

rmse_lin = np.sqrt(mean_squared_error(y_valid, y_pred_lin))
print("Linear Regression RMSE:", rmse_lin)

# モデル学習（LASSO回帰）
lasso = LassoCV(cv=5, random_state=42)
lasso.fit(X_train_scaled, y_train)
y_pred_lasso = lasso.predict(X_valid_scaled)

rmse_lasso = np.sqrt(mean_squared_error(y_valid, y_pred_lasso))
print("LASSO Regression RMSE:", rmse_lasso)
# Out:
# Linear Regression RMSE: 33.20582479252608
# LASSO Regression RMSE: 23.308021900457565

# %%
# NaN をゼロで補完
X_encoded = X_encoded.fillna(0)
X_test_encoded = X_test_encoded.fillna(0)

# %%
# テストデータに対する予測
y_test_pred_lin = linreg.predict(X_test_scaled)
y_test_pred_lasso = lasso.predict(X_test_scaled)

print("Test Prediction (Linear):", y_test_pred_lin[:10])
print("Test Prediction (LASSO):", y_test_pred_lasso[:10])
# Out:
# Test Prediction (Linear): [ 84.03337337  67.807844    62.59207043 131.02287245  83.10343335
#  104.3886688   82.22295335 134.18728692  72.20962365  77.71016025]
# Test Prediction (LASSO): [ 81.19551433  73.92244074  60.91242691  91.51561452  87.03425534
#   81.01700853  77.6884818  100.89734533  81.32263981 101.80836433]

# %%
# 予測結果の表示
pd.DataFrame({"y_test_pred_lin": y_test_pred_lin, "y_test_pred_lasso": y_test_pred_lasso}).head()
# Out:
#    y_test_pred_lin  y_test_pred_lasso
# 0        84.033373          81.195514
# 1        67.807844          73.922441
# 2        62.592070          60.912427
# 3       131.022872          91.515615
# 4        83.103433          87.034255

# %%
# RMSEの可視化
# 既に計算済みの RMSE をまとめる
results = {
    "Linear Regression": [rmse_lin],
    "LASSO Regression": [rmse_lasso]
}

df_results = pd.DataFrame(results, index=["Without Scaling", "With Scaling"])
print(df_results)

# 可視化（棒グラフ）
df_results.plot(kind="bar", figsize=(8, 5))
plt.title("RMSE Comparison (Scaling vs No Scaling)")
plt.ylabel("RMSE")
plt.xticks(rotation=0)
plt.legend(title="Model")
plt.show()
# Out:
#                  Linear Regression  LASSO Regression
# Without Scaling          33.205825         23.308022
# With Scaling             33.205825         23.308022

# %%
# datetime列を変換（yyyy-m-d形式にする）
dates = pd.to_datetime(df_test["datetime"]).dt.strftime("%Y-%-m-%-d")

# 提出用データフレーム作成
submission = pd.DataFrame({
    0: dates,
    1: y_test_pred_lasso  # 予測値（スケーリング後のLASSO予測を例に使用）
})

# ヘッダーなしでCSV保存
submission.to_csv("submission.csv", index=False, header=False)
